# %% [markdown]
# # Final evaluation and replay
#
# This notebook uses reusable modules and keeps BattLeDIM and Calgary separate.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parents[1]))
from ml.src.event_metrics import calculate_point_metrics, detection_delay_minutes
from ml.src.replay import replay_predictions, assert_prediction_consistency

# %% [markdown]
# Run `python scripts/extract_dataset.py` first. Do not approve a model unless validation and latest chronological test periods both contain the required classes.
